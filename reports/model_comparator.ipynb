# %%
#!pip install httpx
#!pip install num2words
#!pip install nest-asyncio
#!pip install gapic-google-cloud-speech-v1beta1
#!pip install google-cloud
#!pip install --upgrade google-cloud-speech
#!pip install jiwer

# %%
from report_helpers import download_dataset
from report_helpers import transcribe_vosk
from report_helpers import transcribe_google
from report_helpers import transcribe_whisper
from report_helpers import evaluate
from report_helpers import plot
from report_helpers import comparator
from report_helpers import examples
import pandas as pd
import os

# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### Load local dataset

# %%
df = pd.read_csv('df.csv')

# %% [markdown]
# ### Prepare dataset

# %%
data_path = './data/'
archive_file_name = 'data_2021_11_23.zip'
URL = 'http://langtea.club/datasets/vosk/'+archive_file_name

# %%
download_dataset(URL, data_path, archive_file_name)

# %% [markdown]
# ### Human transcribation

# %%
df = pd.read_csv(data_path+'data_0.csv', header = 0, sep=';')
df['path'] = 'data/audio'

# %%
for id_, row in df.iloc()[0].items():
    print('\n'+str(id_)+':')
    print(row)

# %% [markdown]
# ### Machine transcribation

# %%
# vosk 1
server = 'ws://192.168.1.23:2700'
transcribations = []
for path, file in df[['path', 'file']].values:
    print(len(transcribations), file)
    phrases = asyncio.get_event_loop().run_until_complete(
        transcribe_vosk(path+'/'+file, server)
    )
    transcribations.append(' '.join([str(item) for item in phrases]))
df['vosk1_text'] = transcribations

# %%
df.to_csv('df.csv')

# %%
# vosk 2
server = 'ws://10.2.4.87:2700'
transcribations = []
for path, file in df[['path', 'file']].values:
    print(len(transcribations), file)
    phrases = asyncio.get_event_loop().run_until_complete(
        transcribe_vosk(path+'/'+file, server)
    )
    transcribations.append(' '.join([str(item) for item in phrases]))
df['vosk2_text'] = transcribations

# %%
df.to_csv('df.csv')

# %%
# google
#df = pd.read_csv('df.csv')
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = 'google_app_cred.json'
transcribations = []
for path, file in df[['path', 'file']].values:
    print(len(transcribations), file)
    transcribations.append(transcribe_google(path + '/' + file))
df['google_text'] = transcribations

# %%
df.to_csv('df.csv')

# %%
# whisper
server_url = 'http://10.2.5.212:8888/transcribe'
transcribations = []
for path, file in df[['path', 'file']].values:
    print(len(transcribations), file)
    phrases = asyncio.get_event_loop().run_until_complete(
        transcribe_whisper(path+'/'+file, server_url)
    )
    transcribations.append(' '.join([str(item) for item in phrases]))
df['whisper_text'] = transcribations
# Out:
# 0 cpu0_2021-11-22_a2021-11-22t08:30:05b_cd_ef_g1637559002.1734887h-in.wav
# 1 cpu1_2021-11-22_a2021-11-22t09:06:03b_cd_ef_g1637561160.1735773h-in.wav
# 2 cpu17_2021-11-22_in_2021-11-22-08-38-52rxtx_R.wav
# 3 cpu21_2021-11-22_a2021-11-22t09:23:56b_cd_ef_g1637562233.1736384h-in.wav
# 4 cpu2_2021-11-22_a2021-11-22t08:30:05b_cd_ef_g1637559002.1734887h-out.wav
# 5 cpu2_2021-11-22_a2021-11-22t09:12:27b_cd_ef_g1637561544.1735974h-in.wav
# 6 cpu2_2021-11-22_a2021-11-22t09:17:19b_cd_ef_g1637561837.1736188h-in.wav
# 7 cpu26_2021-11-22_a2021-11-22t08:18:40b_cd_ef_g1637558318.1734618h-out.wav
# 8 cpu26_2021-11-22_a2021-11-22t09:23:56b_cd_ef_g1637562233.1736384h-out.wav
# 9 cpu3_2021-11-22_a2021-11-22t08:36:25b_cd_ef_g1637559383.1735059h-in.wav
# 10 cpu3_2021-11-22_a2021-11-22t09:12:27b_cd_ef_g1637561544.1735974h-out.wav
# 11 cpu3_2021-11-22_a2021-11-22t09:17:19b_cd_ef_g1637561837.1736188h-out.wav
# 12 cpu3_2021-11-22_in_2021-11-22-08-25-21rxtx_L.wav
# 13 cpu3_2021-11-22_in_2021-11-22-08-25-21rxtx_R.wav
# 14 cpu4_2021-11-22_a2021-11-22t08:36:25b_cd_ef_g1637559383.1735059h-out.wav
# 15 cpu4_2021-11-22_a2021-11-22t08:38:24b_cd_ef_g1637559502.1735128h-in.wav
# 16 cpu4_2021-11-22_a2021-11-22t08:49:33b_cd_ef_g1637560171.1735381h-in.wav
# 17 cpu4_2021-11-22_in_2021-11-22-09-08-29rxtx_L.wav
# 18 cpu5_2021-11-22_a2021-11-22t08:38:24b_cd_ef_g1637559502.1735128h-out.wav
# 19 cpu5_2021-11-22_a2021-11-22t08:49:33b_cd_ef_g1637560171.1735381h-out.wav
# 20 cpu5_2021-11-22_a2021-11-22t09:26:47b_cd_ef_g1637562405.1736439h-out.wav

# %% [markdown]
# ### eval

# %%
evaluate(df, 'vosk1')
evaluate(df, 'vosk2')
evaluate(df, 'google')

# %%
evaluate(df, 'whisper')

# %% [markdown]
# ### save data

# %%
df.to_csv('data_full.csv', index=False)

# %% [markdown]
# ### load data

# %%
df = pd.read_csv('data_full.csv')

# %% [markdown]
# ### plot

# %%
plot(df, ['vosk1', 'vosk2', 'google', 'whisper'])

# %% [markdown]
# ### Aggregate median and compare

# %%
comparator(
    df = df,
    engines = ['vosk1', 'vosk2', 'google', 'whisper'],
    evals = ['wer', 'mer', 'wil']
)
# Out:
# wer:
# vosk1 0.3333333333333333
# vosk2 0.2826086956521739
# google 0.3170731707317073
# whisper 0.2
#
# mer:
# vosk1 0.3265306122448979
# vosk2 0.2727272727272727
# google 0.3170731707317073
# whisper 0.2
#
# wil:
# vosk1 0.484375
# vosk2 0.400555041628122
# google 0.4463554463554463
# whisper 0.2229885057471263

# %% [markdown]
# ### Word Error Rate
# The present de facto standard index for ASR system assessment is the Word Error Rate, which is defined as the proportion of word errors to
# words processed
# ### Match error rate
# Probability of a given match being incorrect
# ### Word information lost
# Simple function of HSDI counts by making use of an equation linking mutual information with Pearson's Large Sample Statistic, and then retaining only dominant terms.
#
# ### Conclusion
# MER and WIL both provide simple CSR performance measures which vary from 0 when there are no errors to 1 when
# there are no hits. They are more suitable than WER for the evaluation of any application in which the proportion of word information communicated is more meaningful than edit cost.
# At low error rates all three give similar scores so that the inappropriate theoretical basis for the WER measure is not noticeable. However, in tests for many real world applications, where significant error rates are common and choosing the best system is very important, the rankings given by each measure start to differ significantly and the risk of incorrect choice of best performing system becomes very real. Statistical tests used with WER can also be applied to MER and WIL. Both MER and WIL have intuitively simple probabilistic interpretations, but in so far as WIL measures the proportion of (mapping sensitive) word information communicated (at least, when N is dominated by H), and communication is mainly what speech is for, it is the preferred measure.
#
# <a href="https://www.researchgate.net/publication/221478089_From_WER_and_RIL_to_MER_and_WIL_improved_evaluation_measures_for_connected_speech_recognition">From_WER_and_RIL_to_MER_and_WIL_improved_evaluatio.pdf</a>

# %%
examples(df, ['human', 'vosk1', 'vosk2', 'google', 'whisper'], 0)
# Out:
# === example 0 ===
#
# human:
# алло доброе утро компания айсберг мастер юсупов по поводу обоев актулаьно еще хорошо я тогда продлю заявку а могу закрывать а ага хорошо
#
# vosk1:
# алло доброе утро компания айсберг мастер юсупов по поводу обоих актуальные нет нет хорошо я тогда продлю заявку а мозга могу закрывать хорошо
#
# vosk2:
# алло доброе утро компания айсберг марш три юсупов по поводу обоих актуальнее чем нет нет хорошо я тогда продлю заявку а мого могу закрывать хорошо
#
# google:
# алло доброе утрокомпания айсберг мастер юсупов по поводу обоев актуально ещё хорошо я тогда продлил заявку а мог могу закрывать а хорошо
#
# whisper:
# алло доброе утро компания айсберг мастер юсупов по поводу обоев актуально еще нет нет я же сказала что надо будет это регулярно ну хорошо я тогда продлю заявку нет все а могу закрывать что нибудь а хорошо
#
# === example 1 ===
#
# human:
# а добрый день меня зовут иван мастер по холодильникам хотел с вами время визита согласовать я постараюсь побыстрее но ориентировочно до одинадцати постараюсь в течении часа подъехать ориентировочно посмотрим хорошо вы мне подскажите номер квартиры пожалуйста да да да все хорошо я постараюсь как можно быстрее к вам подъехать да до свидания
#
# vosk1:
# добрый день меня зовут васька холодильника хотя во время визита соглашалась я постараюсь побыстрее но ориентировочно то одиннадцати постараюсь в течении часа подъехать ориентировочно посмотрим хорошо вы меня подскажите номер квартиры пожалуйста да да все хорошо я постараюсь как можно быстрее к вам подъехать тогда
#
# vosk2:
# добрый день меня зовут иван у мастера по холодильникам хотел с вами время визита согласовать я постараюсь побыстрее но ориентировочно до одиннадцати постараюсь в течение часа подъехать ориентировочно посмотрим хорошо вы мне подскажите номер квартиры пожалуйста да да все хорошо я постараюсь как можно быстрее к вам подъехать итак до свидания
#
# google:
# добрый день меня зовут иван васько по холодильникам хотел с вами время визита согласовать я постараюсь быстрее но ориентировочно до 11:00 постараюсь в течение часа подъехать интересуешься посмотрим хорошо вы мне подскажите номер квартиры пожалуйста когда всё хорошо я постараюсь как можно быстрее вам подъехать когда свидание
#
# whisper:
# и слыша ного нет нет я же сказала что надо будет я перезвоню не сейчас да да закопаться
#
# vosk2:
# слушаю добро нет нет я сказал если надо будет я перезвоню ни о чем да да закопаться
#
# google:
# слушать добронет-нет я сказал если надо будет я перезвоню нет всё да-да-да купайся
#
# whisper:
# слушаю доброе нет нет я же сказала если надо будет я перезвоню нет все да да закрывается
#
# === example 5 ===
#
# human:
# алло здравствуйте это мастер по плите беспокоит мы договаривались на сегодня с вами а в среду да а ну давайте в первой половине дня да все хорошо тогда ожидайте до свидания
#
# vosk1:
# алло здравствуйте это мастер по плите беспокоит мы договорились на сегодня с вами а в среду да а ну давайте в первой половине дня да всё хорошо тогда ожидайте знаю
#
# vosk2:
# алло здравствуйте это мастер по плите беспокоит мы договаривались на сегодня к свану австрия да да ну давайте в первой половине дня да все хорошо тогда ожидайте
#
# google:
# алло здравствуйте это мастер по плите беспокоит мы договаривались на сегодня с вамиа в среду да ну давайте в первой половине дня да всё хорошо тогда ожидайте
#
# whisper:
# алло здравствуйте это мастер по плите беспокоит мы договаривались на сегодня с вами в среду да ну давайте в первой половине дня да все хорошо тогда ожидайте до свидания
#
# === example 6 ===
#
# human:
# але доброе утро это мастер по холодильникам хотел согласовать время моего визита где то если через час подойду нормально будет да ну через час через полтора как вам удобнее все хорошо я понял ага все всего доброго
#
# vosk1:
# аллё доброе утро это мастер по холодильникам хотел согласовать время моего визита где то если через час проезда нормально будет да ну через час через полтора как вам удобнее все хорошо я понял всего доброго
#
# vosk2:
# але доброе утро это мастер по холодильникам хотел согласовать время моего визита где-то если через час проезда нормально будет да ну через час через полтора как вам удобнее все хорошо я понял всего доброго
#
# google:
# алло доброе утро это мастер по холодильникам хотел согласовать время моего визита где-то если сейчас падает нормально будет да ну через часик полтора как вам удобнее всё хорошо я понял всё всего доброго
#
# whisper:
# алло доброе утро это мастер по холодильникам хотел согласовать время моего визита где то если через час подойду нормально будет да ну через час через полтора как вам удобнее все хорошо я понял угу все всего доброго
#
# === example 7 ===
#
# human:
# алло я давала у нас в общем холодильник работает как бы вроде морозит но очень большой шум шумит прям незнаю как вы за вызов сколько берете как это диагностика да ну я перезвоню мы тут посовещаемся с сыном ладно
#
# vosk1:
# и алло я давала у нас восемь холодильник работает кабы вроде морозить на очень большой шум шуметь прямо не знаю как вы того сколько берете как это диагностика да но я перезвоню тебе всем что с сыном ладно
#
# vosk2:
# алло я давала у нас в общем холодильник работает как бы вроде морозить но очень большой шум шуметь прямо не знаю как вы забыли сколько берете как это диагностика да но я перезвоню мы это с сыном ну
#
# google:
# алло я давала у нас в общем холодильник работает как бы вроде морозит но очень большой шум шуметь прям незнайка вызовы за сколько берёте как это диагностика да ну я перезвоню посвящен тут сыну ладно
#
# whisper:
# телефонный звонок ладно
#
# === example 8 ===
#
# human:
#
# vosk1:
# и и и э э ай-ай а а от сдавать его понятно что нет но да в среду в каком время вы придёте хорошо да да до свидания
#
# vosk2:
# ой-ой давайте вы придёте в среду да в среду в какое время вы придёте хорошо да да до свидания
#
# google:
# ойдавайте вы придёте в среду да в среду в какое время вы придёте хорошо да-да до свидания
#
# whisper:
# алло давайте вы придете в среду да в среду в какое время вы придете хорошо да до свидания
#
# === example 11 ===
#
# human:
# алло да сейчас ну давайте я сейчас жене позвоню что и как то и так и так удобно хорошо
#
# vosk1:
# и а аула угу отвечал я сейчас так и так удобно
#
# vosk2:
# аура отвечал я сейчас занят так и так удобно
#
# google:
# погода сейчас сейчас-то и так и так удобно
#
# whisper:
# продолжение следует продолжение
#
# === example 12 ===
#
# human:
# Здравствуйте я позвонила в сервисный сервис айсберге ага девушка неделю назад я вызывала мастера а ну если а я хочу задать вопрос нет заявки у меня нет сейчас а в а бывшую заявку а ну сейчас я вам перезвоню и скажу номер скажу заявки сейчас перезвоню подождите
#
# vosk1:
# и я позвонил в сервисный центр айсберги девушка неделю назад я вызвала мастера а ну же я хочу задать вопрос нет заявки у меня нет сейчас а бывший заявку но сейчас я вам перезвоню и скажу номер скажу номер заявки сейчас перезвоню вам
#
# vosk2:
# я позвонил в сервисный центр айсберги девушка неделю назад я вызвала мастера ну это же а я хочу задать вопрос нет заявки у меня нет сейчас в бывшую заявку ну сейчас я вам перезвоню и скажу номер и скажу номер заявки сейчас перезвоню вам
#
# google:
# сервисный центр айсберги девушка неделю назад я вызвала мастера а ну а я хочу задать вопрос нет заявки у меня нет сейчас в а бывший заявку а ну сейчас я вам перезвоню и скажу номер скажу номер заявки сейчас перезвоню вам подарить
#
# whisper:
# здравствуйте я позвонила в сервисный центр айсберги девушка неделю назад я вызывала мастера ну это же я хочу задать вопрос нет заявки у меня нет сейчас а бывшую заявку ну сейчас я вам перезвоню и скажу номер заявки сейчас перезвоню вам подождите
#
# === example 13 ===
#
# human:
# едина служба сервиса оператор лилия здравствуйте да телефон какой оставляли я его не вижу диктуйте я понимаю я понимаю что вы наш клиент для того что бы понимать о чем мы разговариваем мне нужно найти вашу заявку по этому я ее могу найти нет ну вы говорите неделю на конечно а ее можно найти по номеру заявки хорошо
#
# vosk1:
# и единый сервис оператор лилия здравствуйте да телефон какой оставляли я его не вижу я понимаю я понимаю что вы наш клиент для того чтобы понимать о чем мы разговариваем мне нужно знать вашу заявку поэтому я могу найти нет ну вы говорите неделю нас конечно а её можно найти по номеру заявки хорошо
#
# vosk2:
# единая служба сервиса оператор лилия здравствуйте да телефон какой оставляли и вы не решите кто есть я понимаю я понимаю что вы наш клиент для того чтобы понимать о чем мы разговариваем мне нужно найти вашу заявку поэтому я не могу найти нет ну вы говорите неделю нас конечно а её можно найти по номеру заявки хорошо
#
# google:
# единая служба сервиса оператор юлия здравствуйте да телефон какой оставляли я его не вижу диктуйте доброе утро я понимаю я понимаю что вы наш клиент для того чтобы понимать о чём мы разговариваем не нужно найти вашу заявку поэтому я её могу найти нет ну вы говорите неделю нас конечно а её можно найти по номеру заявки хорошо
#
# whisper:
# единая служба сервиса оператор лилия здравствуйте да телефон какой оставляли я его не вижу диктуйте доброе утро единая служба я понимаю я понимаю что вы наш клиент для того чтобы понимать о чем мы разговариваем мне нужно найти вашу заявку поэтому я ее могу найти нет ну вы говорите неделю назад конечно а ее можно найти по номеру заявки хорошо
#
# === example 14 ===
#
# human:
# алло доброе утро да да да ну не у него кредит не получилось взять вот на следующей неделе в начале прям третьего числа наверно давайте наверно уже договоримся точно нам на денежки будут да да да да да да да да все большое спасибо большое спасибо до свидания
#
# vosk1:
# и она доброе утро да да да но меня кредит и получил зачёт на следующей неделе вначале прям третьего числа на отдавать наверно уже да кларенс точно у нас денежка будут да да да да да да да да все большое спасибо большое спасибо до свидания
#
# vosk2:
# ха оно доброе утро да да да но я её не кредит не получил даже вот на следующей неделе вначале прям третьего числа она давать нам нужно договариваться точно у нам на денежки будут да да да да да да да да все большое спасибо большое спасибо до свидания
#
# google:
# алло доброе утро да-да кредит и получилось знаешь вот на следующей неделе в начале прям 3 давать нами уже договоримся точно нам надо денежки будут да-да-да да-да-да всё спасибо большое спасибо до свидания
#
# whisper:
# алло доброе утро да да да ну у меня кредит не получился вот на следующей неделе вначале три го числа давайте наверное уже договоримся точно у нас деньги будут да да да да да да да да да все большое спасибо большое спасибо до свидания
#
# === example 15 ===
#
# human:
# алло здравствуйте единая служба сервиса по ремонту посудомоечной техники ага да а вы нашли уже да ага я вас понял хорошо ладно извините
#
# vosk1:
# алло здравствуйте единая служба сервиса по ремонту посудомоечной техники ага да вы нашли уже да я вас понял хорошо ладно извините
#
# vosk2:
# алло здравствуйте единая служба сервиса по ремонту посудомоечной техники да выносливы уже да я вас понял хорошо ладно извините
#
# google:
# алло здравствуйте инна служба сервиса по ремонту посудомоечной техники согаз да вы нашли уже да я вас понял хорошо ладно извините
#
# whisper:
# алло здравствуйте единая служба сервиса по ремонту посудомоечной техники ага да вы нашли уже да угу я вас понял хорошо ладно извините
#
# === example 16 ===
#
# human:
# а здравсвуйте айсберг светлана мы с вами договаривались сегодня созвониться а скажите пожалуйста а завтра вам удобно будет с десяти до одинадцати меня принять все завтра значит встретимся до свидания да обязательно перед выездом я звоню до свидания до завтра ага
#
# vosk1:
# здравствуйте айсберг светлана мы с вами договаривались сегодня созвониться скажите пожалуйста а завтра вам удобно будет с десяти до одиннадцати меня принять все завтра значит встретимся до свидания да обязательно перед выездом я звоню это свидание завтра
#
# vosk2:
# дочь здравствуйте айсберг светлана мы с вами договаривались сегодня созвониться скажите пожалуйста а завтра вам удобно будет с десяти до одиннадцати в меня принять все завтра значит встретимся до свидания да обязательно перед выездом я звоню заседание завтра
#
# google:
# здравствуйте айсберг светлана мы с вами договаривались сегодня созвониться скажите пожалуйста а завтра вам удобно будет с 10:00 до 11 у меня принятьвсё завтра значит встретимся до свидания да обязательно перед выездом я звоню
#
# whisper:
# здравствуйте айсберг светлана мы с вами договаривались сегодня созвониться скажите пожалуйста а завтра вам удобно будет с десять до одиннадцать меня принять все завтра значит встретимся до свидания да обязательно перед выездом я звоню до свидания до завтра
#
# === example 17 ===
#
# human:
# это вот по окно окна да да по поводу а да да тогда прошу прощения ну не да не пока не надо потому что я с ним уже разговаривал это я препутал я тут со всеми делаю ага спасибо не надо волновать пока
#
# vosk1:
# промах это вот окно окна да да по поводу ока ах да да тогда прошу прощения да нет пока не надо потому что я с ним уже разговаривал это я перепутал я тут сообщение спасибо не надо волновать просто
#
# vosk2:
# мама это вот по окно окна да да по поводу ага а да да тогда прошу прощения лине да нет пока не надо потому что я с ним уже разговаривал это я перепутал я тут сообщение делаю спасибо не надо волновать
#
# google:
# это вот окно окна да да по поводу акка а да-да тогда прошу прощения пока не надо потому что я с ним уже разговаривал это я перепутал я тут сообщение делаю она спасибо не надо волновать
#
# whisper:
# это вот окно окна да да по поводу окна а да да тогда прошу прощения не не да не пока не надо потому что я с ним уже разговаривал это я перепутал я тут сообщение делаю ага спасибо не надо волновать пока
#
# === example 18 ===
#
# human:
# але добрый день да ага а вы из из айсберга да а вы знаете а пока это я пока на вчера ищу мастера ну да я вчера обзванивал же вот вчера небыло у вас да извините до свидания
#
# vosk1:
# и она ага вы из бархата а пока это я пока ношу вчера ещё мастера ну да я вчера обзванивал зовут вчера не было у вас но извините таня
#
# vosk2:
# але добрый день гага а вы из айсберга да а знаете пока это я пока нож вчера ещё мастерах ну да я вчера обзванивал живот вчера не было у вас до свидания
#
# google:
# алло добрый день дорогая а знаете пока это я пока нас вчера ищу мастера ну давай я вчера звонил вот вчера не было у вас да извините до свидания
#
# whisper:
# алло добрый день да ага а вы из айсберга да вы знаете я пока нашел вчера еще мастера ну да я вчера обзванивал вчера не было у вас ну извините до свидания
#
# === example 19 ===
#
# human:
# але да да хорошо ну вы тогда еще раз позвоните да хорошо ага хорошо все договорились до свидания
#
# vosk1:
# и она да да хорошо но вы тогда ещё раз позвоните да хорошо а хорошо все договорились до свидания
#
# vosk2:
# алло да да хорошо но вы тогда ещё раз позвоните да хорошо хорошо все договорились до свидания
#
# google:
# алло да да хорошо давай тогда ещё позвоните да хорошо спи хорошо всё договорились до свидания
#
# whisper:
# алло да да хорошо ну вы тогда еще раз позвоните да хорошо ага хорошо все договорились до свидания спасибо
#
# === example 20 ===
#
# human:
# алло да да да хорошо приходите ага всего доброго
#
# vosk1:
# и алло да да да хорошо приходите все добро
#
# vosk2:
# эй ха алло да да да хорошо приходите всего доброго
#
# google:
# алло да-да-да хорошо приходите всего доброго
#
# whisper:
# алло да да да хорошо приходите всего доброго
